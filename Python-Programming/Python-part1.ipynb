# %%
# print function
# passing a string
print("Hello world")
# Out:
# Hello world

# %%
print(6)
# Out:
# 6

# %%
print("India","Pakisthan",sep='-',end=' ',)
print("Russia-America")
# Out:
# India-Pakisthan Russia-America

# %%
# int in python
print(1e308)
# Out:
# 1e+308

# %%
print(1e309)
# Out:
# inf

# %%
# float in python
print(1.7e308)
# Out:
# 1.7e+308

# %%
print(1.7e309)
# Out:
# inf

# %%
# variables
# dynamic typing - automatically understands the datatype, no need of datatype declaration
# dynamic binding - can store multiple datatypes, it is not bound to one datatype throughout the program
a=5
a
# Out:
# 5

# %%
a='Hello'
a
# Out:
# 'Hello'

# %%
# declaring multiple variables in a single sentence
a=5;b=6;c=7
print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 7

# %%
a,b,c=2,3,4
print(a)
print(b)
print(c)
# Out:
# 2
# 3
# 4

# %%
a=b=c=10
print(a)
print(b)
print(c)
# Out:
# 10
# 10
# 10

# %%
# keywords and identifiers
# we have 35 keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
# keywords cannot be used as identifiers

# %%
_ = "anusha"
print(_)
# Out:
# anusha

# %%
__ = "anushak"
print(__)
# Out:
# anushak

# %%
_name = "preeti"
print(_name)
# Out:
# preeti

# %%
first1_name = "rahul"
print(first1_name)
# Out:
# rahul

# %%
first_num = input("Enter the first number")
second_num = input("Enter the second number")
# Out:
# Enter the first number4
# Enter the second number5

# %%
print(first_num)
print(second_num)
result = first_num + second_num # string concatenation since input accepts a string since its a universal datatype
# string can hold other datatypes but vice versa is not true
print(result)
# Out:
# 4
# 5
# 45

# %%
# finding the type
type([1,2,3,4])
# Out:
# list

# %%
type(5.6)
# Out:
# float

# %%
type(8)
# Out:
# int

# %%
str('45')
# Out:
# '45'

# %%
# type conversion for compatible convertible datatypes
str(45)
# Out:
# '45'

# %%
bool(34)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
int(4.5)
# Out:
# 4

# %%
float(3)
# Out:
# 3.0

# %%
list('Hello')
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
tuple('Hello')
# Out:
# ('H', 'e', 'l', 'l', 'o')

# %%
set('Hello')
# Out:
# {'H', 'e', 'l', 'o'}

# %%
first_num = int(input("Enter the first number"))
second_num = int(input("Enter the second number"))
result = first_num + second_num
print(result)
# Out:
# Enter the first number20
# Enter the second number30
# 50

# %%
complex(4)
# Out:
# (4+0j)

# %%
name = None
print(name)
# Out:
# None

# %%
# Literals - raw data given to a variable
# numeric, string, boolean, special literals
# numeric literals
# decimal literal below
b = 100
b
# Out:
# 100

# %%
# binary literal - starts with 0b
a = 0b1010
a
# Out:
# 10

# %%
# hexadecimal - starts with 0x
a = 0x12c
a
# Out:
# 300

# %%
# octadecimal
a = 0o312
a
# Out:
# 202

# %%
# float literal
float_1 = 0.5
float_1
# Out:
# 0.5

# %%
float_2 = 1.5e2
# 1.5 * 10^2
float_2
# Out:
# 150.0

# %%
float_3 = 1.5e-3
# 1.5 * 10^-3
float_3
# Out:
# 0.0015

# %%
# complex
x = 3.14j
x.imag
# Out:
# 3.14

# %%
x.real
# Out:
# 0.0

# %%
# string literal
string = 'hello'
string
# Out:
# 'hello'

# %%
string = "me"
string
# Out:
# 'me'

# %%
# no char datatype, stored as string itself
char = "C"
char
# Out:
# 'C'

# %%
# multiline string
"""
this was a good
beginning of a great
day, make sure to
follow it
"""
# Out:
# '\nthis was a good \nbeginning of a great\nday, make sure to \nfollow it \n'

# %%
# unicode strings - like smileys
smileys = u"\U0001f600\U0001f606\U0001f605"
smileys
# Out:
# '😀😆😅'

# %%
# raw strings
raw_string = r"raw\n string#'"

# %%
raw_string
# Out:
# "raw\\n string#'"

# %%
# boolean literal
a = True + 4
# a = 1+4 = 5
a
# Out:
# 5

# %%
b = False + 9
# b = 0+9
b
# Out:
# 9

# %%
# special literals
# None
# when we want to keep a variable in our code without giving it a value
# use None in python
# nothing happens when you use None
# k gives error
# but k=None doesn't
k=None

# %%
k

# %%
anu = None
